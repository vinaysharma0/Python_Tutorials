# %% [markdown]
# ![](../Cover/cover.png)

# %% [markdown]
# Hope you will like my work !
#
# Please SUBSCRIBE channel going through this link down below :
#
# https://www.youtube.com/channel/UCfayWGHJ9JvTic8NHxfK09Q

# %% [markdown]
# -----------------------

# %% [markdown]
# # FILE HANDLING

# %%
import csv

# %%
# Using csv reader only
with open('Favorite TV Shows - Form Responses 1.csv','r') as file:
    reader = csv.reader(file)
    next(reader)
    for row in reader:
        print(row[1])
# Out:
# Punisher
# The Office
# Breaking Bad
# new girl
# archer
# The Office
# Brooklyn99
# Fleabag
# community
# Suits
# Gilmore Girls
# Parks and Recreation
# Umbrella Academy
# avatar the last airbender
# New Girl
# the office
# The Office
# Game of Thrones
# Breaking Bad
# Sherlock
# Breaking Bad
# Dragon Ball Z
# Tiny Words
# Love Island
# The 100
# Outer Banks
# El Marginal
# CS50
# Rick and Morty
# Lost Girl
# Sex education
# Game of Thrones
# Money Heist
# The Office
# Crash Landing on You
# Community
# Tom and Jerry
# Rick and Morty
# Avatar: The Last Airbender
# Friends
# Stranger things
# survivor
# The Office
# The Office
# Frasier
# Suits
# The Office
# Midsomer Murders
# Friends
# Parks & Recreation
# the office
# The Good Place
# Love on the Spectrum
# Euphoria
# The Mandalorian
# Seinfeld
# The Office
# The Boys
# Zeta Gundam
# Mad Men
# Peaky Blinders
# Dark
# Game of Thrones
# Stranger things
# the office
# New Girl
# breaking bad
# The Bachelor/Bachelorette
# ...

# %%
# using Dict Reader (this one is fun)

titles = dict()

with open('Favorite TV Shows - Form Responses 1.csv','r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        title = row['title'].strip().upper()
        
        if title in titles:
            titles[title] += 1
        else:
            titles[title] = 1

for title in sorted(titles, key = lambda title : titles[title], reverse = True):
    print(title, titles[title])
# Out:
# GAME OF THRONES 33
# FRIENDS 27
# THE OFFICE 26
# BREAKING BAD 20
# SUITS 9
# THE BIG BANG THEORY 9
# STRANGER THINGS 8
# BIG BANG THEORY 8
# SHERLOCK 6
# PARKS AND RECREATION 5
# AVATAR THE LAST AIRBENDER 5
# CS50 5
# THE GOOD PLACE 5
# LOST 5
# SUPERNATURAL 5
# GREY'S ANATOMY 5
# HOW I MET YOUR MOTHER 5
# THE 100 4
# MONEY HEIST 4
# AVATAR: THE LAST AIRBENDER 4
# MAD MEN 4
# SILICON VALLEY 4
# TWIN PEAKS 4
# CS50 WITH DAVID MALAN 4
# FUTURAMA 4
# ONE PIECE 4
# NEW GIRL 3
# FLEABAG 3
# COMMUNITY 3
# GILMORE GIRLS 3
# RICK AND MORTY 3
# SEX EDUCATION 3
# SEINFELD 3
# THE BOYS 3
# LA CASA DE PAPEL 3
# MODERN FAMILY 3
# LUCIFER 3
# BOJACK HORSEMAN 3
# OZARK 3
# DEXTER 3
# THE AMAZING WORLD OF GUMBALL 3
# GOT 3
# BROOKLYN99 2
# PEAKY BLINDERS 2
# BETTER CALL SAUL 2
# EMILY IN PARIS 2
# SPONGEBOB 2
# BONES 2
# PSYCH 2
# THE FLASH 2
# NARUTO 2
# THE SIMPSONS 2
# NARCOS 2
# MERLIN 2
# ALF 2
# BLACK MIRROR 2
# GAMES OF THRONES 2
# FRIENDS ETC. 2
# NCIS 2
# THE WIRE 2
# MR ROBOT 2
# ...

# %%
# this one is more fun , where we count the number of times the show is watched by giving input

title = input('title : ').strip().upper()

counter = 0

with open('Favorite TV Shows - Form Responses 1.csv','r') as file:
    
    reader = csv.DictReader(file)
    
    for row in reader:
        
        if (title == row['title'].strip().upper()):
            counter += 1
            
print(counter)
# Out:
# title :  game of thrones
# 33

# %% [markdown]
# ----------------------------
